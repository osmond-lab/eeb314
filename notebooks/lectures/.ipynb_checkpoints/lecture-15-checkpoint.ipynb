# %% [markdown]
# # Lecture 15: The evolution of ploidy
#
# ## Lecture overview
#
# 1. [Summary](#section1)

# %% [markdown]
# <span id='section1'></span>
# ## 1. Summary
# <hr>

# %% [markdown]
# This lecture hasn't been typset yet. Please see section 8.4 of the textbook for details in the meantime.
#
# Practice questions from the textbook: 8.9
